# %%
# %pip install tensorflow scikit-learn pandas numpy
# Out:
# Requirement already satisfied: tensorflow in c:\users\jr\.conda\envs\solol\lib\site-packages (2.15.0)
# Collecting scikit-learn
#   Using cached scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting pandas
#   Using cached pandas-2.2.0-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy in c:\users\jr\.conda\envs\solol\lib\site-packages (1.26.4)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\jr\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jr\.conda\envs\solol\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jr\.conda\envs\solol\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jr\.conda\envs\solol\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jr\.conda\envs\solol\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jr\.conda\envs\solol\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jr\.conda\envs\solol\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jr\.conda\envs\solol\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jr\.conda\envs\solol\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jr\.conda\envs\solol\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\jr\.conda\envs\solol\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jr\.conda\envs\solol\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Using cached scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl (10.6 MB)
# Using cached pandas-2.2.0-cp311-cp311-win_amd64.whl (11.6 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached scipy-1.12.0-cp311-cp311-win_amd64.whl (46.2 MB)
# Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, scipy, joblib, scikit-learn, pandas
# Successfully installed joblib-1.3.2 pandas-2.2.0 pytz-2024.1 scikit-learn-1.4.0 scipy-1.12.0 threadpoolctl-3.2.0 tzdata-2023.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
#https://www.kaggle.com/code/teowaihong/exercise-pose-classification-with-pytorch/notebook
# Load the dataset
file_path = '../train.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 5
#       2 #https://www.kaggle.com/code/teowaihong/exercise-pose-classification-with-pytorch/notebook
#       3 # Load the dataset
#       4 file_path = '../train.csv'
# ----> 5 df = pd.read_csv(file_path)
#       7 # Display the first few rows of the dataframe
#       8 df.head()
#
# File c:\Users\JR\.conda\envs\sololeveling\Lib\site-packages\pandas\io\parsers\readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\JR\.conda\envs\sololeveling\Lib\site-packages\pandas\io\parsers\readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File c:\Users\JR\.conda\envs\sololeveling\Lib\site-packages\pandas\io\parsers\readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\JR\.conda\envs\sololeveling\Lib\site-packages\pandas\io\parsers\readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File c:\Users\JR\.conda\envs\sololeveling\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../train.csv'

# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Suppress TensorFlow warnings (optional, not recommended)
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Load the dataset
df = pd.read_csv('train.csv')  # Make sure the path is correct

# Extract features and labels
X = df.drop(['pose_id', 'pose'], axis=1)
y = df['pose']

# Encode the labels to integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# One-hot encode the labels
y_categorical = to_categorical(y_encoded)

# Normalize the feature data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_categorical, test_size=0.2, random_state=42)

# Reshape input data for LSTM. LSTM expects data in the shape of [samples, time steps, features].
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Define the model architecture
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.5))
model.add(LSTM(32))
model.add(Dropout(0.5))
model.add(Dense(y_train.shape[1], activation='softmax'))  # The output layer with a softmax activation

# Compile the model with the Adam optimizer
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=64, validation_split=0.3)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test accuracy: {accuracy*100:.2f}%')

# Save the model in the native Keras format
# model.save('exercise_recognition_model2.keras')
# Out:
# C:\Users\JR\AppData\Local\Temp\ipykernel_1400\30546127.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From c:\Users\JR\.conda\envs\solol\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\JR\.conda\envs\solol\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\JR\.conda\envs\solol\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\JR\.conda\envs\solol\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 10/10 [==============================] - 7s 138ms/step - loss: 2.3041 - accuracy: 0.1272 - val_loss: 2.2808 - val_accuracy: 0.3220
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 2.2663 - accuracy: 0.2382 - val_loss: 2.2457 - val_accuracy: 0.4318
# Epoch 3/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.2224 - accuracy: 0.3507 - val_loss: 2.2060 - val_accuracy: 0.4508
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 2.1790 - accuracy: 0.3948 - val_loss: 2.1585 - val_accuracy: 0.4773
# Epoch 5/100
# 10/10 [==============================] - 0s 10ms/step - loss: 2.1259 - accuracy: 0.4225 - val_loss: 2.0991 - val_accuracy: 0.4811
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 2.0621 - accuracy: 0.4454 - val_loss: 2.0305 - val_accuracy: 0.4697
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.9821 - accuracy: 0.4502 - val_loss: 1.9522 - val_accuracy: 0.4735
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.9062 - accuracy: 0.4747 - val_loss: 1.8692 - val_accuracy: 0.4811
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.8380 - accuracy: 0.4600 - val_loss: 1.7852 - val_accuracy: 0.4924
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.7328 - accuracy: 0.5024 - val_loss: 1.7018 - val_accuracy: 0.5189
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.6574 - accuracy: 0.4927 - val_loss: 1.6210 - val_accuracy: 0.5341
# Epoch 12/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.5972 - accuracy: 0.5106 - val_loss: 1.5392 - val_accuracy: 0.5758
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.5221 - accuracy: 0.5367 - val_loss: 1.4641 - val_accuracy: 0.5795
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4370 - accuracy: 0.5677 - val_loss: 1.3944 - val_accuracy: 0.5909
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.3951 - accuracy: 0.5775 - val_loss: 1.3291 - val_accuracy: 0.6364
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.3350 - accuracy: 0.6052 - val_loss: 1.2708 - val_accuracy: 0.6553
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.2829 - accuracy: 0.6150 - val_loss: 1.2216 - val_accuracy: 0.6515
# Epoch 18/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.2164 - accuracy: 0.6330 - val_loss: 1.1753 - val_accuracy: 0.6780
# Epoch 19/100
# 10/10 [==============================] - 0s 16ms/step - loss: 1.1975 - accuracy: 0.6362 - val_loss: 1.1326 - val_accuracy: 0.6667
# Epoch 20/100
# 10/10 [==============================] - 0s 10ms/step - loss: 1.1730 - accuracy: 0.6232 - val_loss: 1.0957 - val_accuracy: 0.6705
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.1134 - accuracy: 0.6623 - val_loss: 1.0646 - val_accuracy: 0.6705
# Epoch 22/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0874 - accuracy: 0.6591 - val_loss: 1.0378 - val_accuracy: 0.6780
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0743 - accuracy: 0.6688 - val_loss: 1.0136 - val_accuracy: 0.6856
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0270 - accuracy: 0.6868 - val_loss: 0.9923 - val_accuracy: 0.6856
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9983 - accuracy: 0.6998 - val_loss: 0.9692 - val_accuracy: 0.6894
# Epoch 26/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9625 - accuracy: 0.7129 - val_loss: 0.9489 - val_accuracy: 0.6894
# Epoch 27/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9434 - accuracy: 0.7129 - val_loss: 0.9358 - val_accuracy: 0.7008
# Epoch 28/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9659 - accuracy: 0.6998 - val_loss: 0.9200 - val_accuracy: 0.6894
# Epoch 29/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9051 - accuracy: 0.7259 - val_loss: 0.8992 - val_accuracy: 0.6970
# Epoch 30/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.9051 - accuracy: 0.7227 - val_loss: 0.8844 - val_accuracy: 0.7045
# Epoch 31/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8917 - accuracy: 0.7162 - val_loss: 0.8776 - val_accuracy: 0.7045
# Epoch 32/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8772 - accuracy: 0.7292 - val_loss: 0.8644 - val_accuracy: 0.7045
# Epoch 33/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.8221 - accuracy: 0.7423 - val_loss: 0.8497 - val_accuracy: 0.7083
# Epoch 34/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.8384 - accuracy: 0.7520 - val_loss: 0.8384 - val_accuracy: 0.7235
# Epoch 35/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7939 - accuracy: 0.7569 - val_loss: 0.8335 - val_accuracy: 0.7235
# Epoch 36/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7742 - accuracy: 0.7781 - val_loss: 0.8290 - val_accuracy: 0.7197
# Epoch 37/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7814 - accuracy: 0.7423 - val_loss: 0.8250 - val_accuracy: 0.7083
# Epoch 38/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7800 - accuracy: 0.7651 - val_loss: 0.8145 - val_accuracy: 0.7083
# Epoch 39/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7773 - accuracy: 0.7406 - val_loss: 0.8117 - val_accuracy: 0.7083
# Epoch 40/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7177 - accuracy: 0.7781 - val_loss: 0.8090 - val_accuracy: 0.7121
# Epoch 41/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7582 - accuracy: 0.7569 - val_loss: 0.8030 - val_accuracy: 0.7121
# Epoch 42/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7682 - accuracy: 0.7635 - val_loss: 0.7971 - val_accuracy: 0.7235
# Epoch 43/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.7491 - accuracy: 0.7814 - val_loss: 0.7898 - val_accuracy: 0.7273
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.7079 - accuracy: 0.7863 - val_loss: 0.7874 - val_accuracy: 0.7273
# Epoch 45/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6810 - accuracy: 0.7896 - val_loss: 0.7813 - val_accuracy: 0.7159
# Epoch 46/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7045 - accuracy: 0.7814 - val_loss: 0.7746 - val_accuracy: 0.7235
# Epoch 47/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6903 - accuracy: 0.7961 - val_loss: 0.7661 - val_accuracy: 0.7311
# Epoch 48/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7197 - accuracy: 0.7635 - val_loss: 0.7664 - val_accuracy: 0.7386
# Epoch 49/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6649 - accuracy: 0.7830 - val_loss: 0.7641 - val_accuracy: 0.7311
# Epoch 50/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6558 - accuracy: 0.8075 - val_loss: 0.7590 - val_accuracy: 0.7235
# Epoch 51/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6128 - accuracy: 0.8026 - val_loss: 0.7567 - val_accuracy: 0.7311
# Epoch 52/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6257 - accuracy: 0.8010 - val_loss: 0.7534 - val_accuracy: 0.7311
# Epoch 53/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6367 - accuracy: 0.7830 - val_loss: 0.7466 - val_accuracy: 0.7311
# Epoch 54/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6178 - accuracy: 0.8222 - val_loss: 0.7474 - val_accuracy: 0.7386
# Epoch 55/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6229 - accuracy: 0.8091 - val_loss: 0.7437 - val_accuracy: 0.7424
# Epoch 56/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6243 - accuracy: 0.8026 - val_loss: 0.7422 - val_accuracy: 0.7386
# Epoch 57/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6019 - accuracy: 0.8206 - val_loss: 0.7372 - val_accuracy: 0.7386
# Epoch 58/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6106 - accuracy: 0.7977 - val_loss: 0.7307 - val_accuracy: 0.7386
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6217 - accuracy: 0.8238 - val_loss: 0.7279 - val_accuracy: 0.7500
# Epoch 60/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6226 - accuracy: 0.7896 - val_loss: 0.7306 - val_accuracy: 0.7500
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5826 - accuracy: 0.8254 - val_loss: 0.7288 - val_accuracy: 0.7500
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5694 - accuracy: 0.8173 - val_loss: 0.7278 - val_accuracy: 0.7614
# Epoch 63/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5698 - accuracy: 0.8254 - val_loss: 0.7304 - val_accuracy: 0.7576
# Epoch 64/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5656 - accuracy: 0.8222 - val_loss: 0.7228 - val_accuracy: 0.7576
# Epoch 65/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5949 - accuracy: 0.8124 - val_loss: 0.7091 - val_accuracy: 0.7652
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5778 - accuracy: 0.8189 - val_loss: 0.7051 - val_accuracy: 0.7652
# Epoch 67/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5674 - accuracy: 0.8303 - val_loss: 0.7015 - val_accuracy: 0.7652
# Epoch 68/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5389 - accuracy: 0.8238 - val_loss: 0.7017 - val_accuracy: 0.7614
# Epoch 69/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5186 - accuracy: 0.8336 - val_loss: 0.7108 - val_accuracy: 0.7576
# Epoch 70/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.5206 - accuracy: 0.8401 - val_loss: 0.7133 - val_accuracy: 0.7614
# Epoch 71/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5431 - accuracy: 0.8287 - val_loss: 0.7083 - val_accuracy: 0.7652
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5174 - accuracy: 0.8532 - val_loss: 0.7047 - val_accuracy: 0.7614
# Epoch 73/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5278 - accuracy: 0.8450 - val_loss: 0.7016 - val_accuracy: 0.7614
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4946 - accuracy: 0.8483 - val_loss: 0.6981 - val_accuracy: 0.7652
# Epoch 75/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4943 - accuracy: 0.8548 - val_loss: 0.6916 - val_accuracy: 0.7689
# Epoch 76/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4801 - accuracy: 0.8597 - val_loss: 0.6932 - val_accuracy: 0.7765
# Epoch 77/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5284 - accuracy: 0.8271 - val_loss: 0.6943 - val_accuracy: 0.7765
# Epoch 78/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5155 - accuracy: 0.8401 - val_loss: 0.6853 - val_accuracy: 0.7727
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5068 - accuracy: 0.8434 - val_loss: 0.6807 - val_accuracy: 0.7841
# Epoch 80/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4630 - accuracy: 0.8499 - val_loss: 0.6771 - val_accuracy: 0.7765
# Epoch 81/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4830 - accuracy: 0.8532 - val_loss: 0.6681 - val_accuracy: 0.7803
# Epoch 82/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4620 - accuracy: 0.8597 - val_loss: 0.6769 - val_accuracy: 0.7765
# Epoch 83/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4591 - accuracy: 0.8744 - val_loss: 0.6845 - val_accuracy: 0.7803
# Epoch 84/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4791 - accuracy: 0.8467 - val_loss: 0.6866 - val_accuracy: 0.7765
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4628 - accuracy: 0.8744 - val_loss: 0.6864 - val_accuracy: 0.7841
# Epoch 86/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4512 - accuracy: 0.8581 - val_loss: 0.6883 - val_accuracy: 0.7841
# Epoch 87/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4618 - accuracy: 0.8515 - val_loss: 0.6850 - val_accuracy: 0.7879
# Epoch 88/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4739 - accuracy: 0.8515 - val_loss: 0.6792 - val_accuracy: 0.7879
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4514 - accuracy: 0.8613 - val_loss: 0.6724 - val_accuracy: 0.7879
# Epoch 90/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4397 - accuracy: 0.8760 - val_loss: 0.6697 - val_accuracy: 0.7917
# Epoch 91/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4328 - accuracy: 0.8744 - val_loss: 0.6697 - val_accuracy: 0.7917
# Epoch 92/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3935 - accuracy: 0.8972 - val_loss: 0.6718 - val_accuracy: 0.8030
# Epoch 93/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4133 - accuracy: 0.8891 - val_loss: 0.6677 - val_accuracy: 0.7955
# Epoch 94/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4086 - accuracy: 0.8825 - val_loss: 0.6747 - val_accuracy: 0.8030
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4517 - accuracy: 0.8515 - val_loss: 0.6754 - val_accuracy: 0.7879
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4044 - accuracy: 0.8760 - val_loss: 0.6640 - val_accuracy: 0.7917
# Epoch 97/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4466 - accuracy: 0.8597 - val_loss: 0.6467 - val_accuracy: 0.8068
# Epoch 98/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4339 - accuracy: 0.8760 - val_loss: 0.6423 - val_accuracy: 0.8182
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4202 - accuracy: 0.8793 - val_loss: 0.6465 - val_accuracy: 0.8333
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4364 - accuracy: 0.8793 - val_loss: 0.6600 - val_accuracy: 0.8068
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4500 - accuracy: 0.8636
# Test accuracy: 86.36%

# %%
import joblib

model.save('exercise_recognition_model2.keras')
joblib.dump(label_encoder, 'label_encoder.joblib')
joblib.dump(scaler, 'scaler.save')
# Out:
# ['scaler.save']

# %%
X.shape
# Out:
# (1097, 99)

# %%
X.shape
# Out:
# (1097, 99)

# %%
X_scaled.shape
# Out:
# (1097, 99)

# %%
X_scaled[0]
# len(X_scaled[0])
# Out:
# array([-0.01846408, -0.35136801, -0.43380374, -0.01423244, -0.33611576,
#        -0.39064476, -0.011851  , -0.33698777, -0.39038209, -0.00916741,
#        -0.33869498, -0.39020498, -0.02209725, -0.33621503, -0.39326897,
#        -0.02429428, -0.33665148, -0.39328232, -0.02690407, -0.337595  ,
#        -0.39327653, -0.00708791, -0.36153249, -0.21746426, -0.0325054 ,
#        -0.35922929, -0.23026225, -0.01086571, -0.37034367, -0.38898305,
#        -0.02027584, -0.36593201, -0.39197694,  0.07842886, -0.53365071,
#        -0.11733317, -0.12744374, -0.52965324, -0.25243946,  0.36768495,
#        -0.95264376, -0.46061719, -0.31788686, -0.94633139, -0.41436297,
#        -0.01988921, -0.64407127, -0.41167044,  0.02937561, -0.65899601,
#        -0.16938626, -0.10460604, -0.60917717, -0.37384261,  0.11895501,
#        -0.61683695, -0.14003466, -0.09850709, -0.57625807, -0.31783688,
#         0.10857716, -0.58589046, -0.07249857, -0.07202244, -0.57679705,
#        -0.39418575,  0.07541366, -0.58949388, -0.13901103,  0.41085805,
#        -0.12141255,  0.11021138, -0.41085803,  0.12141522, -0.11021138,
#         0.39266864,  0.59219739,  0.182647  , -0.3250283 ,  0.60659906,
#        -0.09899043,  0.3804499 ,  0.56467245,  0.11160653, -0.3180445 ,
#         0.57699615, -0.0969936 ,  0.33080535,  0.59442372,  0.09897357,
#        -0.28811029,  0.59083971, -0.10427327,  0.4585513 ,  0.45026349,
#         0.02122462, -0.39331951,  0.49289314, -0.20296686])

# %%
X_train[0][0]
# Out:
# array([ 0.41617666, -0.54199642,  2.12426878,  0.50227236, -0.50173999,
#         2.16599033,  0.53993988, -0.47267311,  2.16618151,  0.57055689,
#        -0.4566771 ,  2.1656488 ,  0.41960468, -0.57593987,  2.22679459,
#         0.39860402, -0.5979867 ,  2.22670082,  0.39244534, -0.59676057,
#         2.22667751,  0.69315296, -0.34580717,  2.24133103,  0.47143475,
#        -0.49997207,  2.55198436,  0.51699261, -0.46664315,  2.18079017,
#         0.45343643, -0.4994396 ,  2.26745217,  1.03679348, -0.19435584,
#         1.95716476,  0.38210414, -0.34385625,  2.59415533,  1.02146283,
#         0.1867917 ,  0.95092317, -0.0485329 , -0.09349672,  1.62960403,
#         0.41876864, -0.56525461,  0.46878732,  0.28190479, -0.68092139,
#         0.58393186,  0.2651808 , -0.65040667,  0.41368289,  0.35410563,
#        -0.74438725,  0.47165447,  0.26205475, -0.6742622 ,  0.57968237,
#         0.39220955, -0.74659971,  0.62497147,  0.30521895, -0.65433948,
#         0.54202748,  0.39309067, -0.72668455,  0.62131652,  1.09769382,
#         1.04928651, -0.7675284 , -1.0976938 , -1.0492941 ,  0.7675284 ,
#        -0.18829935,  1.47223031, -2.19702257, -2.21445067,  0.24714705,
#        -0.24761521, -0.23083412,  2.17679527, -2.33407297, -2.15971136,
#         0.36458422, -0.64698461, -0.26127612,  2.14396409, -2.31686549,
#        -2.09026397,  0.61370786, -0.6700403 , -0.31442705,  1.90023211,
#        -2.50222765, -2.32408871, -0.04591048, -0.79609923])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Assuming X_train, X_test, y_train, y_test are already defined and preprocessed from your dataset
# Load the dataset
df = pd.read_csv('train.csv')  # Make sure the path is correct

# Extract features and labels
X = df.drop(['pose_id', 'pose'], axis=1)
y = df['pose']

# Encode the labels to integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# One-hot encode the labels
y_categorical = to_categorical(y_encoded)

# Normalize the feature data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_categorical, test_size=0.2, random_state=42)

# Reshape input data for LSTM. LSTM expects data in the shape of [samples, time steps, features].
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Define a slightly modified model architecture
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))  # Adjusted number of units
model.add(Dropout(0.4))  # Slightly adjusted dropout rate
model.add(LSTM(25))  # Adjusted number of units in the second LSTM layer
model.add(Dropout(0.3))  # Adjusted dropout rate
model.add(Dense(y_train.shape[1], activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2)  # Adjusted epochs and batch size

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/30
# 22/22 [==============================] - 8s 72ms/step - loss: 2.2724 - accuracy: 0.2282 - val_loss: 2.2378 - val_accuracy: 0.4830
# Epoch 2/30
# 22/22 [==============================] - 0s 6ms/step - loss: 2.1901 - accuracy: 0.4579 - val_loss: 2.1575 - val_accuracy: 0.5114
# Epoch 3/30
# 22/22 [==============================] - 0s 8ms/step - loss: 2.0884 - accuracy: 0.4822 - val_loss: 2.0377 - val_accuracy: 0.5341
# Epoch 4/30
# 22/22 [==============================] - 0s 6ms/step - loss: 1.9323 - accuracy: 0.4893 - val_loss: 1.8818 - val_accuracy: 0.5057
# Epoch 5/30
# 22/22 [==============================] - 0s 6ms/step - loss: 1.7725 - accuracy: 0.5036 - val_loss: 1.7146 - val_accuracy: 0.4886
# Epoch 6/30
# 22/22 [==============================] - 0s 5ms/step - loss: 1.5984 - accuracy: 0.5193 - val_loss: 1.5584 - val_accuracy: 0.5057
# Epoch 7/30
# 22/22 [==============================] - 0s 6ms/step - loss: 1.4497 - accuracy: 0.5421 - val_loss: 1.4293 - val_accuracy: 0.5455
# Epoch 8/30
# 22/22 [==============================] - 0s 6ms/step - loss: 1.3497 - accuracy: 0.5663 - val_loss: 1.3267 - val_accuracy: 0.5568
# Epoch 9/30
# 22/22 [==============================] - 0s 6ms/step - loss: 1.2243 - accuracy: 0.6277 - val_loss: 1.2435 - val_accuracy: 0.5739
# Epoch 10/30
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1639 - accuracy: 0.6362 - val_loss: 1.1752 - val_accuracy: 0.6136
# Epoch 11/30
# 22/22 [==============================] - 0s 6ms/step - loss: 1.1092 - accuracy: 0.6562 - val_loss: 1.1146 - val_accuracy: 0.6307
# Epoch 12/30
# 22/22 [==============================] - 0s 11ms/step - loss: 1.0405 - accuracy: 0.6876 - val_loss: 1.0770 - val_accuracy: 0.6136
# Epoch 13/30
# 22/22 [==============================] - 0s 9ms/step - loss: 0.9587 - accuracy: 0.7133 - val_loss: 1.0301 - val_accuracy: 0.6420
# Epoch 14/30
# 22/22 [==============================] - 0s 7ms/step - loss: 0.9323 - accuracy: 0.6890 - val_loss: 0.9987 - val_accuracy: 0.6534
# Epoch 15/30
# 22/22 [==============================] - 0s 6ms/step - loss: 0.9248 - accuracy: 0.7190 - val_loss: 0.9787 - val_accuracy: 0.6534
# Epoch 16/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8800 - accuracy: 0.7461 - val_loss: 0.9676 - val_accuracy: 0.6705
# Epoch 17/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8221 - accuracy: 0.7461 - val_loss: 0.9232 - val_accuracy: 0.6705
# Epoch 18/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8429 - accuracy: 0.7332 - val_loss: 0.9095 - val_accuracy: 0.6761
# Epoch 19/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8286 - accuracy: 0.7432 - val_loss: 0.8930 - val_accuracy: 0.6932
# Epoch 20/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7754 - accuracy: 0.7760 - val_loss: 0.8757 - val_accuracy: 0.6818
# Epoch 21/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7604 - accuracy: 0.7504 - val_loss: 0.8606 - val_accuracy: 0.6875
# Epoch 22/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7671 - accuracy: 0.7532 - val_loss: 0.8539 - val_accuracy: 0.6932
# Epoch 23/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7043 - accuracy: 0.7946 - val_loss: 0.8462 - val_accuracy: 0.6761
# Epoch 24/30
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6807 - accuracy: 0.8203 - val_loss: 0.8280 - val_accuracy: 0.6875
# Epoch 25/30
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6875 - accuracy: 0.7874 - val_loss: 0.8254 - val_accuracy: 0.6932
# Epoch 26/30
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6740 - accuracy: 0.7746 - val_loss: 0.8058 - val_accuracy: 0.6875
# Epoch 27/30
# 22/22 [==============================] - 0s 11ms/step - loss: 0.6628 - accuracy: 0.8003 - val_loss: 0.7927 - val_accuracy: 0.6932
# Epoch 28/30
# 22/22 [==============================] - 0s 9ms/step - loss: 0.6420 - accuracy: 0.7960 - val_loss: 0.7885 - val_accuracy: 0.6932
# Epoch 29/30
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6385 - accuracy: 0.8017 - val_loss: 0.7833 - val_accuracy: 0.6932
# Epoch 30/30
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6137 - accuracy: 0.7946 - val_loss: 0.7724 - val_accuracy: 0.7102
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.7909
# Test accuracy: 79.09%
