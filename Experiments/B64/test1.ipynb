# %%
b64_string = "..."

# %%
import cv2
import numpy as np
import base64

# Decode the Base64 string
image_data = base64.b64decode(b64_string)

# Convert the bytes data to a numpy array
nparr = np.frombuffer(image_data, np.uint8)

# Decode image from numpy array
image = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
print(image.shape)
# If the image is loaded successfully, convert it to BGR
if image is not None:
    #convert the image to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    #read the image
    # OpenCV loads the image in BGR format by default so no conversion is required
    # But if you wanted to, say, convert to RGB, you could use cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # We will just use the image as is
    pass
else:
    print("The image could not be decoded from the provided string.")
# Out:
# (720, 1280, 3)

# %%
import tensorflow as tf

model = tf.keras.models.load_model("best_model_grid_search.h5")
# Out:
# WARNING:tensorflow:From c:\Users\JR\.conda\envs\solol\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\JR\.conda\envs\solol\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
import mediapipe as mp

mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Process the frame with MediaPipe Pose
results = pose.process(image_rgb)

if results.pose_landmarks:
    # Draw the pose annotations on the frame
    mp.solutions.drawing_utils.draw_landmarks(
        image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS
    )

    # Extract landmarks
    landmarks = (
        [landmark.x for landmark in results.pose_landmarks.landmark]
        + [landmark.y for landmark in results.pose_landmarks.landmark]
        + [landmark.z for landmark in results.pose_landmarks.landmark]
    )

    # Flatten the landmarks into a single array
    landmarks = np.array(landmarks).flatten()
    landmarks = landmarks.reshape(1, -1)

# %%
print(landmarks.shape)
# Out:
# (1, 99)

# %%
map = {0: "squat_up", 1: "squat_down", 2: 'jumping_jack_down', 3: 'jumping_jack_up', 4: 'curl_down', 5: 'curl_up', 6: 'lunge_up', 7: 'lunge_down', 8: 'high_knee_down', 9: 'high_knee_up', 10: 'push_up_up', 11: 'push_up_down', 12: 'back_row_down', 13: 'back_row_up'}

prediction = model(landmarks, training=False)
# Convert prediction to numpy array if it's not already (for TensorFlow 2.x)
prediction = prediction.numpy()

# Get the index of the max confidence
predicted_index = np.argmax(prediction)

# Get the max confidence value
confidence = np.max(prediction)

# Check if the confidence is above the threshold
if confidence > 0.5:
    # Display the class with the highest confidence
    label = map[predicted_index]
else:
    # Display 'Unknown' if confidence is not high enough
    label = "Unknown"
    
print(label)
# Out:
# lunge_down

# %%
# display the image using opencv
cv2.imshow("mediapipe", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[[ 85  93  86]
#   [ 85  93  86]
#   [ 85  92  87]
#   ...
#   [ 69  81  87]
#   [ 70  82  88]
#   [ 73  85  91]]
#
#  [[ 86  94  87]
#   [ 86  94  87]
#   [ 86  93  88]
#   ...
#   [ 66  78  84]
#   [ 65  77  83]
#   [ 67  79  85]]
#
#  [[ 87  94  89]
#   [ 87  94  89]
#   [ 87  94  89]
#   ...
#   [ 49  61  65]
#   [ 57  72  75]
#   [ 69  84  87]]
#
#  ...
#
#  [[185 172 174]
#   [186 173 175]
#   [186 173 175]
#   ...
#   [  0   0  30]
#   [  0   0  31]
#   [  0   0  31]]
#
#  [[187 174 176]
#   [186 173 175]
#   [186 173 175]
#   ...
#   [  0   0  30]
#   [  0   0  30]
#   [  0   0  30]]
#
#  [[187 174 176]
#   [186 173 175]
#   [185 172 174]
#   ...
#   [  0   0  30]
#   [  0   0  30]
#   [  0   0  30]]]
# (720, 1280, 3)
